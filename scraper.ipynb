# %%
# autoreload edited modules in the notebook
# %reload_ext autoreload
# %autoreload 2

# %%
from utils.scrap import save_pdf, fetch_all_pages
from pathlib import Path

# %%
thesis_id = 43569
pages_number = 178
# url = 
# pages =

# %%
all_pages = fetch_all_pages(
    thesis_id=thesis_id,
    pages_number=pages_number,
    custom_sleep_time=0.1,
    random_sleep_time=False,
)
save_path = Path('thesis') / f'{thesis_id}.pdf'
save_pdf(all_pages=all_pages, pdf_path=save_path)
# Out:
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=1&pc=
# Page 1 is done
# i = 1
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=2&pc=
# Page 2 is done
# i = 2
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=3&pc=
# Page 3 is done
# i = 3
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=4&pc=
# Page 4 is done
# i = 4
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=5&pc=
# Page 5 is done
# i = 5
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=6&pc=
# Page 6 is done
# i = 6
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=7&pc=
# Page 7 is done
# i = 7
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=8&pc=
# Page 8 is done
# i = 8
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=9&pc=
# Page 9 is done
# i = 9
# break = 177
# https://utdlib.ut.ac.ir/DigitalFiles/PdfPage/43569?pn=10&pc=
# Page 10 is done
# i = 10
# ...
